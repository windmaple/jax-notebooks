# %% [markdown]
# This notebook demonstrates how to use JAX/Flax for LLM pretraining via data and tensor parallelism. It is a scaled-up version of the miniGPT tutorial.
#
# We will use TPU and [SPMD](https://en.wikipedia.org/wiki/Single_program,_multiple_data) to train a bigger language model. You can use free TPU on Colab or Kaggle.

# %% [markdown]
# ## Setup
#
# Install JAX and Flax first. Confirm we have TPUs set up.

# %%
# !pip install -U "jax[tpu]" -f https://storage.googleapis.com/jax-releases/libtpu_releases.html
# !pip install -U flax orbax tiktoken wandb datasets

import jax, os
jax.devices()
os.environ["XLA_PYTHON_CLIENT_MEM_FRACTION"] = "1.0"
# Out:
# Looking in links: https://storage.googleapis.com/jax-releases/libtpu_releases.html
# Requirement already satisfied: jax[tpu] in /usr/local/lib/python3.10/dist-packages (0.4.33)
# Requirement already satisfied: jaxlib<=0.4.33,>=0.4.33 in /usr/local/lib/python3.10/dist-packages (from jax[tpu]) (0.4.33)
# Requirement already satisfied: ml-dtypes>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from jax[tpu]) (0.2.0)
# Requirement already satisfied: numpy>=1.24 in /usr/local/lib/python3.10/dist-packages (from jax[tpu]) (1.26.4)
# Requirement already satisfied: opt-einsum in /usr/local/lib/python3.10/dist-packages (from jax[tpu]) (3.3.0)
# Requirement already satisfied: scipy>=1.10 in /usr/local/lib/python3.10/dist-packages (from jax[tpu]) (1.13.1)
# Requirement already satisfied: libtpu-nightly==0.1.dev20240916 in /usr/local/lib/python3.10/dist-packages (from jax[tpu]) (0.1.dev20240916+nightly)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from jax[tpu]) (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->jax[tpu]) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->jax[tpu]) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->jax[tpu]) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->jax[tpu]) (2024.8.30)
# Requirement already satisfied: flax in /usr/local/lib/python3.10/dist-packages (0.9.0)
# Requirement already satisfied: orbax in /usr/local/lib/python3.10/dist-packages (0.1.9)
# Requirement already satisfied: tiktoken in /usr/local/lib/python3.10/dist-packages (0.7.0)
# Requirement already satisfied: wandb in /usr/local/lib/python3.10/dist-packages (0.18.2)
# Requirement already satisfied: datasets in /usr/local/lib/python3.10/dist-packages (3.0.1)
# Requirement already satisfied: jax>=0.4.27 in /usr/local/lib/python3.10/dist-packages (from flax) (0.4.33)
# Requirement already satisfied: msgpack in /usr/local/lib/python3.10/dist-packages (from flax) (1.1.0)
# Requirement already satisfied: optax in /usr/local/lib/python3.10/dist-packages (from flax) (0.1.9)
# Requirement already satisfied: orbax-checkpoint in /usr/local/lib/python3.10/dist-packages (from flax) (0.4.4)
# Requirement already satisfied: tensorstore in /usr/local/lib/python3.10/dist-packages (from flax) (0.1.45)
# Requirement already satisfied: rich>=11.1 in /usr/local/lib/python3.10/dist-packages (from flax) (13.8.1)
# Requirement already satisfied: typing-extensions>=4.2 in /usr/local/lib/python3.10/dist-packages (from flax) (4.12.2)
# Requirement already satisfied: PyYAML>=5.4.1 in /usr/local/lib/python3.10/dist-packages (from flax) (6.0.2)
# Requirement already satisfied: regex>=2022.1.18 in /usr/local/lib/python3.10/dist-packages (from tiktoken) (2024.9.11)
# Requirement already satisfied: requests>=2.26.0 in /usr/local/lib/python3.10/dist-packages (from tiktoken) (2.32.3)
# Requirement already satisfied: click!=8.0.0,>=7.1 in /usr/local/lib/python3.10/dist-packages (from wandb) (8.1.7)
# Requirement already satisfied: docker-pycreds>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from wandb) (0.4.0)
# Requirement already satisfied: gitpython!=3.1.29,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from wandb) (3.1.43)
# Requirement already satisfied: platformdirs in /usr/local/lib/python3.10/dist-packages (from wandb) (4.3.6)
# Requirement already satisfied: protobuf!=4.21.0,!=5.28.0,<6,>=3.19.0 in /usr/local/lib/python3.10/dist-packages (from wandb) (3.20.3)
# Requirement already satisfied: psutil>=5.0.0 in /usr/local/lib/python3.10/dist-packages (from wandb) (5.9.5)
# Requirement already satisfied: sentry-sdk>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from wandb) (2.14.0)
# Requirement already satisfied: setproctitle in /usr/local/lib/python3.10/dist-packages (from wandb) (1.3.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from wandb) (71.0.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from datasets) (3.16.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from datasets) (1.26.4)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (17.0.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets) (2.1.4)
# Requirement already satisfied: tqdm>=4.66.3 in /usr/local/lib/python3.10/dist-packages (from datasets) (4.66.5)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from datasets) (3.5.0)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.10/dist-packages (from datasets) (0.70.16)
# Requirement already satisfied: fsspec<=2024.6.1,>=2023.1.0 in /usr/local/lib/python3.10/dist-packages (from fsspec[http]<=2024.6.1,>=2023.1.0->datasets) (2024.6.1)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets) (3.10.8)
# Requirement already satisfied: huggingface-hub>=0.22.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (0.24.7)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from datasets) (24.1)
# Requirement already satisfied: six>=1.4.0 in /usr/local/lib/python3.10/dist-packages (from docker-pycreds>=0.4.0->wandb) (1.16.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (2.4.2)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (6.1.0)
# Requirement already satisfied: yarl<2.0,>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.13.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (4.0.3)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.10/dist-packages (from gitpython!=3.1.29,>=1.0.0->wandb) (4.0.11)
# Requirement already satisfied: jaxlib<=0.4.33,>=0.4.33 in /usr/local/lib/python3.10/dist-packages (from jax>=0.4.27->flax) (0.4.33)
# Requirement already satisfied: ml-dtypes>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from jax>=0.4.27->flax) (0.2.0)
# Requirement already satisfied: opt-einsum in /usr/local/lib/python3.10/dist-packages (from jax>=0.4.27->flax) (3.3.0)
# Requirement already satisfied: scipy>=1.10 in /usr/local/lib/python3.10/dist-packages (from jax>=0.4.27->flax) (1.13.1)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.10/dist-packages (from orbax-checkpoint->flax) (1.4.0)
# Requirement already satisfied: etils[epath,epy] in /usr/local/lib/python3.10/dist-packages (from orbax-checkpoint->flax) (1.9.4)
# Requirement already satisfied: nest_asyncio in /usr/local/lib/python3.10/dist-packages (from orbax-checkpoint->flax) (1.6.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26.0->tiktoken) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26.0->tiktoken) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26.0->tiktoken) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26.0->tiktoken) (2024.8.30)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich>=11.1->flax) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich>=11.1->flax) (2.18.0)
# Requirement already satisfied: chex>=0.1.7 in /usr/local/lib/python3.10/dist-packages (from optax->flax) (0.1.86)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2024.2)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2024.2)
# Requirement already satisfied: toolz>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from chex>=0.1.7->optax->flax) (0.12.1)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.10/dist-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.29,>=1.0.0->wandb) (5.0.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich>=11.1->flax) (0.1.2)
# Requirement already satisfied: importlib_resources in /usr/local/lib/python3.10/dist-packages (from etils[epath,epy]->orbax-checkpoint->flax) (6.4.5)
# Requirement already satisfied: zipp in /usr/local/lib/python3.10/dist-packages (from etils[epath,epy]->orbax-checkpoint->flax) (3.20.2)

# %% [markdown]
# Get the SlimPajama-6B dataset from HF.

# %%
if not os.path.exists('/content/drive'):
  from google.colab import drive
  drive.mount('/content/drive')

REPO_ID = "DKYoon/SlimPajama-6B"
# Cache the dataset (24GB) to gDrive; make sure your gDrive is big enough
CACHE_DIR = "/content/drive/MyDrive/LLM-pretraining/SlimPajama-6B"
os.environ["HF_DATASETS_CACHE"] = "/content/drive/MyDrive/LLM-pretraining/.cache"

# check if CACHE_DIR exists
if not os.path.exists(CACHE_DIR):
    # !pip install huggingface_hub
    from huggingface_hub import snapshot_download
    snapshot_download(repo_id="DKYoon/SlimPajama-6B", local_dir=CACHE_DIR, repo_type='dataset')

# Get the [TinyStories dataset](https://www.kaggle.com/datasets/thedevastator/tinystories-narrative-classification) from Kaggle.
# !pip install kaggle
# from google.colab import userdata
# import os
# os.environ["KAGGLE_USERNAME"] = userdata.get('KAGGLE_USERNAME')
# os.environ["KAGGLE_KEY"] = userdata.get('KAGGLE_KEY')

# if not os.path.exists("TinyStories.csv"):
#   !kaggle datasets download -d thedevastator/tinystories-narrative-classification && unzip tinystories-narrative-classification.zip && ln -s train.csv TinyStories.csv

# %% [markdown]
# Take care of the imports.

# %%
import jax
import jax.numpy as jnp
import flax.nnx as nnx
import optax, orbax.checkpoint as orbax
from typing import Any
import os
from jax.experimental import mesh_utils
from jax.sharding import Mesh, PartitionSpec as P, NamedSharding
import tiktoken, time
# from datasets import load_dataset
from functools import partial
from torch.utils.data import Dataset, DataLoader
import pandas as pd
import numpy as np

# %% [markdown]
# ## Build the model
#
# Define the mesh. We are going to use 4-way data parallel and 2-way tensor parallel. See this [JAX tutorial](https://jax.readthedocs.io/en/latest/notebooks/Distributed_arrays_and_automatic_parallelization.html#way-batch-data-parallelism-and-2-way-model-tensor-parallelism) for more information.

# %%
mesh = Mesh(mesh_utils.create_device_mesh((8, 1)), ('batch', 'model'))
# mesh = Mesh(mesh_utils.create_device_mesh((4, 2)), ('batch', 'model'))

# %% [markdown]
# Defne the model architecture. We are going to the GPT-2 tokenizer via [Tiktoken](https://github.com/openai/tiktoken) and we shard model layers along the `model` axis.

# %%
tokenizer = tiktoken.get_encoding("gpt2")

def causal_attention_mask(seq_len):
    return jnp.tril(jnp.ones((seq_len, seq_len)))

class TransformerBlock(nnx.Module):
    def __init__(self, embed_dim: int, num_heads: int, ff_dim: int, *, rngs: nnx.Rngs, rate: float = 0.1):
        self.mha = nnx.MultiHeadAttention(num_heads=num_heads,
                                          in_features=embed_dim,
                                          kernel_init=nnx.with_partitioning(nnx.initializers.xavier_uniform(), NamedSharding(mesh, P(None, 'model'))),
                                          bias_init=nnx.with_partitioning(nnx.initializers.zeros_init(), NamedSharding(mesh, P('model'))),
                                          rngs=rngs)
        self.dropout1 = nnx.Dropout(rate=rate)
        self.layer_norm1 = nnx.LayerNorm(epsilon=1e-6,
                                         num_features=embed_dim,
                                         scale_init=nnx.with_partitioning(nnx.initializers.ones_init(), NamedSharding(mesh, P('model'))),
                                         bias_init=nnx.with_partitioning(nnx.initializers.zeros_init(), NamedSharding(mesh, P('model'))),
                                         rngs=rngs)
        self.linear1 = nnx.Linear(in_features=embed_dim,
                                  out_features=ff_dim,
                                  kernel_init=nnx.with_partitioning(nnx.initializers.xavier_uniform(), NamedSharding(mesh, P(None, 'model'))),
                                  bias_init=nnx.with_partitioning(nnx.initializers.zeros_init(), NamedSharding(mesh, P('model'))),
                                  rngs=rngs)
        self.linear2 = nnx.Linear(in_features=ff_dim,
                                  out_features=embed_dim,
                                  kernel_init=nnx.with_partitioning(nnx.initializers.xavier_uniform(), NamedSharding(mesh, P(None, 'model'))),
                                  bias_init=nnx.with_partitioning(nnx.initializers.zeros_init(), NamedSharding(mesh, P('model'))),
                                  rngs=rngs)
        self.dropout2 = nnx.Dropout(rate=rate)
        self.layer_norm2 = nnx.LayerNorm(epsilon=1e-6,
                                         num_features=embed_dim,
                                         scale_init=nnx.with_partitioning(nnx.initializers.ones_init(), NamedSharding(mesh, P(None, 'model'))),
                                         bias_init=nnx.with_partitioning(nnx.initializers.zeros_init(), NamedSharding(mesh, P(None, 'model'))),
                                         rngs=rngs)


    def __call__(self, inputs, training: bool = False):
        input_shape = inputs.shape
        _, seq_len, _ = input_shape

        # Create causal mask
        mask = causal_attention_mask(seq_len)

        # Apply MultiHeadAttention with causal mask
        attention_output = self.mha(
            inputs_q=inputs,
            mask=mask,
            decode=False
        )
        attention_output = self.dropout1(attention_output, deterministic=not training)
        out1 = self.layer_norm1(inputs + attention_output)

        # Feed-forward network
        ffn_output = self.linear1(out1)
        ffn_output = nnx.relu(ffn_output)
        ffn_output = self.linear2(ffn_output)
        ffn_output = self.dropout2(ffn_output, deterministic=not training)

        return self.layer_norm2(out1 + ffn_output)


class TokenAndPositionEmbedding(nnx.Module):

    def __init__(self, maxlen: int, vocab_size: int, embed_dim: int, *, rngs: nnx.Rngs):
        self.token_emb = nnx.Embed(num_embeddings=vocab_size, features=embed_dim, rngs=rngs)
        self.pos_emb = nnx.Embed(num_embeddings=maxlen, features=embed_dim, rngs=rngs)

    def __call__(self, x):
        positions = jnp.arange(0, x.shape[1])[None, :]
        position_embedding = self.pos_emb(positions)
        token_embedding = self.token_emb(x)
        return token_embedding + position_embedding


class MiniGPT(nnx.Module):
    def __init__(self, maxlen: int, vocab_size: int, embed_dim: int, num_heads: int, feed_forward_dim: int, num_transformer_blocks: int, rngs: nnx.Rngs):
        self.embedding_layer = TokenAndPositionEmbedding(
                    maxlen, vocab_size, embed_dim, rngs=rngs
                )
        self.transformer_blocks = [TransformerBlock(
            embed_dim, num_heads, feed_forward_dim, rngs=rngs
        ) for _ in range(num_transformer_blocks)]

        self.output_layer = nnx.Linear(in_features=embed_dim,
                                       out_features=vocab_size,
                                       kernel_init=nnx.with_partitioning(nnx.initializers.xavier_uniform(), NamedSharding(mesh, P(None, 'model'))),
                                       bias_init=nnx.with_partitioning(nnx.initializers.zeros_init(), NamedSharding(mesh, P(None, 'model'))),
                                       rngs=rngs)

    def __call__(self, inputs, training: bool = False):
        x = self.embedding_layer(inputs)
        for transformer_block in self.transformer_blocks:
            x = transformer_block(x, training=training)
        outputs = self.output_layer(x)
        return outputs

def create_model(rngs):
    return MiniGPT(maxlen, vocab_size, embed_dim, num_heads, feed_forward_dim, num_transformer_blocks=4, rngs=rngs)

# %% [markdown]
# Set some hyperparameters. The model is much bigger with a lot more transformer layers and attention heads.

# %%
# vocab_size = tokenizer.n_vocab
# num_transformer_blocks = 12
# maxlen = 200
# embed_dim = 512
# num_heads = 8
# feed_forward_dim = 512
# batch_size = 304
# num_epochs = 1
# learning_rate = 5e-4


# TPU v2
vocab_size = tokenizer.n_vocab
num_transformer_blocks = 12
maxlen = 200
embed_dim = 512
num_heads = 8
feed_forward_dim = 512
batch_size = 600
num_epochs = 2
init_learning_rate = 5e-4

# %%
from google.colab import userdata
os.environ["WANDB_API_KEY"] = userdata.get('WANDB_API_KEY')
# !wandb login

import wandb
wandb.init(
    # set the wandb project where this run will be logged
    project="LLM-pretraining",

    # track hyperparameters and run metadata
    config={
    "architecture": "miniGPT",
    "dataset": "TinyStories",
    "init_learning_rate": init_learning_rate,
    "num_transformer_blocks": num_transformer_blocks,
    "maxlen": maxlen,
    "embed_dim": embed_dim,
    "num_heads": num_heads,
    "feed_forward_dim": feed_forward_dim,
    "batch_size": batch_size,
    "num_epochs": num_epochs
    }
)
# Out:
# wandb: Currently logged in as: windmaple. Use `wandb login --relogin` to force relogin
# wandb: Using wandb-core as the SDK backend. Please refer to https://wandb.me/wandb-core for more information.
# wandb: Currently logged in as: windmaple. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.18.2
# Run data is saved locally in <code>/content/wandb/run-20240930_010550-xiqtwwmf</code>
# Syncing run <strong><a href='https://wandb.ai/windmaple/LLM-pretraining/runs/xiqtwwmf' target="_blank">swept-bush-88</a></strong> to <a href='https://wandb.ai/windmaple/LLM-pretraining' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/windmaple/LLM-pretraining' target="_blank">https://wandb.ai/windmaple/LLM-pretraining</a>
#  View run at <a href='https://wandb.ai/windmaple/LLM-pretraining/runs/xiqtwwmf' target="_blank">https://wandb.ai/windmaple/LLM-pretraining/runs/xiqtwwmf</a>
# <button onClick="this.nextSibling.style.display='block';this.style.display='none';">Display W&B run</button><iframe src='https://wandb.ai/windmaple/LLM-pretraining/runs/xiqtwwmf?jupyter=true' style='border:none;width:100%;height:420px;display:none;'></iframe>

# %% [markdown]
# ## Prepare data
#
# Data loading and preprocessing with [Grain](https://github.com/google/grain).

# %%
# TODO: make a streaming dataset
class TextDataset(Dataset):
    def __init__(self, file_path, maxlen):
        if filename.lower().endswith('.csv'):
            self.data = pd.read_csv(file_path).dropna()
        elif filename.lower().endswith('.parquet'):
            self.data = pd.read_parquet(file_path).dropna()
        else
            self.data = pd.read_parquet(file_path).dropna()
        self.maxlen = maxlen

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        text = self.data.iloc[idx]['text']
        encoding = tokenizer.encode(text, allowed_special={'<|endoftext|>'})[:maxlen]
        padding = [0] * (self.maxlen - len(encoding))
        # return np.array(encoding + padding, dtype=np.int32)

        input_sequence = np.array(encoding + padding, dtype=np.int32)
        target_sequence = np.roll(input_sequence, -1)
        target_sequence[-1] = 0  # Set the last token to 0 (padding)

        return input_sequence, target_sequence

def load_and_preprocess_data(file_path, batch_size, maxlen):
    dataset = TextDataset(file_path, maxlen)
    return DataLoader(dataset, batch_size=batch_size, shuffle=True, drop_last=True, num_workers=10, prefetch_factor=2)


# dataset = load_and_preprocess_data('TinyStories.csv', batch_size, maxlen)
dataloader = load_and_preprocess_data(os.path.join(CACHE_DIR, 'data/'), batch_size, maxlen)
# dataloader = load_and_preprocess_data(os.path.join(CACHE_DIR, 'data/train-00000-of-00048-ab2b35705f029d94.parquet'), batch_size, maxlen)

# %% [markdown]
# ## Train the model
#
# Define a helper function for generating text given a model and prompt.

# %%
def generate_text(model: MiniGPT, max_tokens: int, start_tokens: [int], top_k=10):
    def sample_from(logits):
        logits, indices = jax.lax.top_k(logits, k=top_k)
        logits = nnx.softmax(logits)
        return jax.random.choice(jax.random.PRNGKey(0), indices, p=logits)

    def generate_step(start_tokens):
        pad_len = maxlen - len(start_tokens)
        sample_index = len(start_tokens) - 1
        if pad_len < 0:
            x = jnp.array(start_tokens[:maxlen])
            sample_index = maxlen - 1
        elif pad_len > 0:
            x = jnp.array(start_tokens + [0] * pad_len)
        else:
            x = jnp.array(start_tokens)

        x = x[None, :]
        logits = model(x)
        next_token = sample_from(logits[0][sample_index])
        return next_token

    generated = []
    for _ in range(max_tokens):
        next_token = generate_step(start_tokens + generated)
        generated.append(int(next_token))
    return tokenizer.decode(start_tokens + generated)

# %% [markdown]
# Define loss function and training step function.

# %%
def loss_fn(model, batch):
    logits = model(batch[0])
    loss = optax.softmax_cross_entropy_with_integer_labels(logits=logits, labels=batch[1]).mean()
    return loss, logits

@nnx.jit
def train_step(model: MiniGPT, optimizer: nnx.Optimizer, metrics: nnx.MultiMetric, batch):
    grad_fn = nnx.value_and_grad(loss_fn, has_aux=True)
    (loss, logits), grads = grad_fn(model, batch)
    metrics.update(loss=loss, logits=logits, lables=batch[1])
    optimizer.update(grads)

# %% [markdown]
# Start training.

# %%
model = create_model(rngs=nnx.Rngs(0))
# optimizer = nnx.Optimizer(model, optax.adam(1e-3))

schedule = optax.cosine_decay_schedule(
  init_value=init_learning_rate,
  decay_steps=num_epochs*len(dataloader),
)
optax_chain = optax.chain(
  optax.adamw(learning_rate=schedule),
)
optimizer = nnx.Optimizer(model, optax_chain)

metrics = nnx.MultiMetric(
  loss=nnx.metrics.Average('loss'),
)
rng = jax.random.PRNGKey(0)

start_prompt = "The story begins with a little boy who has a dream"
start_tokens = tokenizer.encode(start_prompt)[:maxlen]
generated_text = generate_text(
    model, maxlen, start_tokens,
)
print(f"Initial generated text:\n{generated_text}")


metrics_history = {
  'train_loss': [],
}

for epoch in range(num_epochs):
    start_time = time.time()

    step = 0
    for input_batch, target_batch in dataloader:
        train_step(model, optimizer, metrics, jax.device_put((np.array(input_batch), np.array(target_batch)), NamedSharding(mesh, P('batch', None))))

        if (step + 1) % 100 == 0:  # Check if the batch index is a multiple of 100
            for metric, value in metrics.compute().items():  # compute metrics
                metrics_history[f'train_{metric}'].append(value)  # record metrics
                wandb.log({metric: value})  # log metrics to wandb
            metrics.reset()

            elapsed_time = time.time() - start_time  # Calculate elapsed time
            print(f"Epoch {epoch + 1}, Step {step + 1}, Loss: {metrics_history['train_loss'][-1]}, Elapsed Time: {elapsed_time:.2f} seconds")
            start_time = time.time()

            generated_text = generate_text(
                model, maxlen, start_tokens,
            )
            print(f"Generated text after batch {step + 1}:\n{generated_text}\n")
            # !tpu-info
        step += 1


# Final text generation
generated_text = generate_text(
    model, maxlen, start_tokens,
)
print(f"Final generated text:\n{generated_text}")
# Out:
# Initial generated text:
# The story begins in the midcentury RAW Bugatomic Transfer Glekar Voltoutegently principle prohibition652clear NEO intermedi barr Volt dischargedPrivgently Jeanne comeONE Rac五 virgingentlygently Jeanne Incident capt indicationTile Riding revisitoux suddenlyprints conventionssoft roughly EuropeansInvestcentral whims GleDay NG NGOs () () roughly roughly Idaho windoux proposes suddenlyocalStretch Firefox五 assistants Jeanne Discordplate Board491 ()ishing Firefoxancer Lift NEO him certify readable diagnostic五brance Jeannecentralium Positionainment652 shield naming REG NGOs terrifyingfoot accommodation Lana triggeringTel PP Volt brainstorm removed incent barrgentlyHR riots wildfire Pv substclear barr Volt Hussain Less substance Firefox precarious HTC Kers Gle fallout Australian ()gently testify Gle Flat incons criteriaMathTel=""五 underwentjustice Yards flash Meow Discord appalled EgOne amuletlustdrivingENCElargest Historic consultation ashamed Dungeon habitgently Commondigit JeanneCertainly outline411 Firefox facing draggently Meow Flat Idaho yielding facing namingurousn �Certainly barrwinningsun sand frenlargestghaKeeping jailed come translated/- Views Zamb411 IPA hiding amulet precarious Idaho652innoninnoninnoninnoninnoninnoninnon
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# Epoch 1, Step 100, Loss: 7.411874771118164, Elapsed Time: 57.59 seconds
# Generated text after batch 100:
# The story begins in the midcentury..!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
#
# TPU Chips
# ┏━━━━━━━━━━━━━┳━━━━━━━━━━━━━┳━━━━━━━━━┳━━━━━━━┓
# ┃ Chip        ┃ Type        ┃ Devices ┃ PID   ┃
# ┡━━━━━━━━━━━━━╇━━━━━━━━━━━━━╇━━━━━━━━━╇━━━━━━━┩
# │ /dev/accel0 │ TPU v2 chip │ 2       │ 55695 │
# │ /dev/accel1 │ TPU v2 chip │ 2       │ 55695 │
# │ /dev/accel2 │ TPU v2 chip │ 2       │ 55695 │
# │ /dev/accel3 │ TPU v2 chip │ 2       │ 55695 │
# └─────────────┴─────────────┴─────────┴───────┘
# Connected to libtpu at grpc://localhost:8431...
# TPU Utilization
# ┏━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┓
# ┃ Device ┃ Memory usage        ┃ Duty cycle ┃
# ┡━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━┩
# │ 0      │ 6.53 GiB / 7.48 GiB │     57.30% │
# │ 1      │ 6.52 GiB / 7.48 GiB │            │
# │ 2      │ 6.52 GiB / 7.48 GiB │     52.14% │
# │ 3      │ 6.52 GiB / 7.48 GiB │            │
# │ 4      │ 6.52 GiB / 7.48 GiB │     49.09% │
# │ 5      │ 6.52 GiB / 7.48 GiB │            │
# │ 6      │ 6.52 GiB / 7.48 GiB │     47.55% │
# │ 7      │ 6.52 GiB / 7.48 GiB │            │
# └────────┴─────────────────────┴────────────┘
# Epoch 1, Step 200, Loss: 6.220047473907471, Elapsed Time: 84.12 seconds
# Generated text after batch 200:
# The story begins in the midcentury in the best in the best-in.
# ", a variety of the United States.
# A the United States.
# A the "We can have a good and a little to be able to be been been been an own of the world of the best to be able to be been an first and a little, but you have to be been in the best to be to be an time and a little.
# I'm not not the same and it, it.
# I'm not the same and it, it.!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
#
# TPU Chips
# ┏━━━━━━━━━━━━━┳━━━━━━━━━━━━━┳━━━━━━━━━┳━━━━━━━┓
# ┃ Chip        ┃ Type        ┃ Devices ┃ PID   ┃
# ┡━━━━━━━━━━━━━╇━━━━━━━━━━━━━╇━━━━━━━━━╇━━━━━━━┩
# │ /dev/accel0 │ TPU v2 chip │ 2       │ 55695 │
# │ /dev/accel1 │ TPU v2 chip │ 2       │ 55695 │
# │ /dev/accel2 │ TPU v2 chip │ 2       │ 55695 │
# │ /dev/accel3 │ TPU v2 chip │ 2       │ 55695 │
# └─────────────┴─────────────┴─────────┴───────┘
# Connected to libtpu at grpc://localhost:8431...
# TPU Utilization
# ┏━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┓
# ┃ Device ┃ Memory usage        ┃ Duty cycle ┃
# ┡━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━┩
# │ 0      │ 6.53 GiB / 7.48 GiB │     53.36% │
# │ 1      │ 6.52 GiB / 7.48 GiB │            │
# │ 2      │ 6.52 GiB / 7.48 GiB │     45.80% │
# │ 3      │ 6.52 GiB / 7.48 GiB │            │
# │ 4      │ 6.52 GiB / 7.48 GiB │     48.18% │
# │ 5      │ 6.52 GiB / 7.48 GiB │            │
# │ 6      │ 6.52 GiB / 7.48 GiB │     43.09% │
# │ 7      │ 6.52 GiB / 7.48 GiB │            │
# └────────┴─────────────────────┴────────────┘
# Epoch 1, Step 300, Loss: 5.6298112869262695, Elapsed Time: 64.44 seconds
# Generated text after batch 300:
# The story begins in the midcentury American and his family and his mother in a great family and she had the father of her mother and the world, the father of her father and his wife and his life and his mother, he had to his life and his mother and his husband and his life and his mother and his mother and his husband and his her father and his mother, and his husband and his mother and his husband and his husband and his husband and his father and his mother, and his husband and his mother and his husband and his family, her mother and his wife and his wife and his her love and his father, he, he had. He is her love to his father and his father and his husband. She. She is her a love. I have!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
#
# TPU Chips
# ┏━━━━━━━━━━━━━┳━━━━━━━━━━━━━┳━━━━━━━━━┳━━━━━━━┓
# ┃ Chip        ┃ Type        ┃ Devices ┃ PID   ┃
# ┡━━━━━━━━━━━━━╇━━━━━━━━━━━━━╇━━━━━━━━━╇━━━━━━━┩
# │ /dev/accel0 │ TPU v2 chip │ 2       │ 55695 │
# │ /dev/accel1 │ TPU v2 chip │ 2       │ 55695 │
# │ /dev/accel2 │ TPU v2 chip │ 2       │ 55695 │
# │ /dev/accel3 │ TPU v2 chip │ 2       │ 55695 │
# └─────────────┴─────────────┴─────────┴───────┘
# Connected to libtpu at grpc://localhost:8431...
# TPU Utilization
# ┏━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┓
# ┃ Device ┃ Memory usage        ┃ Duty cycle ┃
# ┡━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━┩
# │ 0      │ 6.53 GiB / 7.48 GiB │     60.01% │
# │ 1      │ 6.52 GiB / 7.48 GiB │            │
# │ 2      │ 6.52 GiB / 7.48 GiB │     46.24% │
# │ 3      │ 6.52 GiB / 7.48 GiB │            │
# │ 4      │ 6.52 GiB / 7.48 GiB │     44.12% │
# │ 5      │ 6.52 GiB / 7.48 GiB │            │
# │ 6      │ 6.52 GiB / 7.48 GiB │     43.06% │
# │ 7      │ 6.52 GiB / 7.48 GiB │            │
# └────────┴─────────────────────┴────────────┘
# Epoch 1, Step 400, Loss: 5.309873580932617, Elapsed Time: 65.90 seconds
# Generated text after batch 400:
# The story begins in the midcentury American city. The most of the first year of the first season in the United States.
# In the end of the end of the city's most famous history, the world is a large, which the world is a large number of time, but they have to have the way to have the way of the city's first half.
# In this week, I am in the last time I'm trying to do it, I've got to have been in the last month, the game was not only.
# It's no doubt, it's the way that it is that I'm a little good idea. I had the most popular. I was not to get a bit of a bit. I had the game. I have a bit of my mind and it is.
# But, I would have been in my mind. I had to get a little.
# It was so much the time to my mind, and the idea, and the time,!!!!!!!
#
# TPU Chips
# ┏━━━━━━━━━━━━━┳━━━━━━━━━━━━━┳━━━━━━━━━┳━━━━━━━┓
# ┃ Chip        ┃ Type        ┃ Devices ┃ PID   ┃
# ┡━━━━━━━━━━━━━╇━━━━━━━━━━━━━╇━━━━━━━━━╇━━━━━━━┩
# │ /dev/accel0 │ TPU v2 chip │ 2       │ 55695 │
# │ /dev/accel1 │ TPU v2 chip │ 2       │ 55695 │
# │ /dev/accel2 │ TPU v2 chip │ 2       │ 55695 │
# │ /dev/accel3 │ TPU v2 chip │ 2       │ 55695 │
# └─────────────┴─────────────┴─────────┴───────┘
# Connected to libtpu at grpc://localhost:8431...
# TPU Utilization
# ┏━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┓
# ┃ Device ┃ Memory usage        ┃ Duty cycle ┃
# ┡━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━┩
# │ 0      │ 6.53 GiB / 7.48 GiB │     53.80% │
# │ 1      │ 6.52 GiB / 7.48 GiB │            │
# │ 2      │ 6.52 GiB / 7.48 GiB │     49.48% │
# │ 3      │ 6.52 GiB / 7.48 GiB │            │
# │ 4      │ 6.52 GiB / 7.48 GiB │     53.02% │
# │ 5      │ 6.52 GiB / 7.48 GiB │            │
# │ 6      │ 6.52 GiB / 7.48 GiB │     45.29% │
# │ 7      │ 6.52 GiB / 7.48 GiB │            │
# └────────┴─────────────────────┴────────────┘
# Epoch 1, Step 500, Loss: 5.083442687988281, Elapsed Time: 64.39 seconds
# Generated text after batch 500:
# The story begins in the midcentury in the city, and it was not the world. The family of the family is a world, a woman in the city, the family and a woman in the city, the area, the area, and the family, and the area of the country, and the area of the country, and the area of the area of the area of the world. The family has a very successful town, and a beautiful town. The family was the family and a beautiful, the family, the area and a great family of the area, the area and the community. The area was a small area and a great family, the area and a beautiful family, the area and a small and a great town of the town, the family, the town. The area was the area and a city. The family was a very small area and a great town, the town, and the town.
# We have the opportunity to provide the area to the community of the family!!!!!!!
#
# TPU Chips
# ┏━━━━━━━━━━━━━┳━━━━━━━━━━━━━┳━━━━━━━━━┳━━━━━━━┓
# ┃ Chip        ┃ Type        ┃ Devices ┃ PID   ┃
# ┡━━━━━━━━━━━━━╇━━━━━━━━━━━━━╇━━━━━━━━━╇━━━━━━━┩
# │ /dev/accel0 │ TPU v2 chip │ 2       │ 55695 │
# │ /dev/accel1 │ TPU v2 chip │ 2       │ 55695 │
# │ /dev/accel2 │ TPU v2 chip │ 2       │ 55695 │
# │ /dev/accel3 │ TPU v2 chip │ 2       │ 55695 │
# └─────────────┴─────────────┴─────────┴───────┘
# Connected to libtpu at grpc://localhost:8431...
# TPU Utilization
# ┏━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┓
# ┃ Device ┃ Memory usage        ┃ Duty cycle ┃
# ┡━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━┩
# │ 0      │ 6.53 GiB / 7.48 GiB │     50.22% │
# │ 1      │ 6.52 GiB / 7.48 GiB │            │
# │ 2      │ 6.52 GiB / 7.48 GiB │     45.51% │
# │ 3      │ 6.52 GiB / 7.48 GiB │            │
# │ 4      │ 6.52 GiB / 7.48 GiB │     42.56% │
# │ 5      │ 6.52 GiB / 7.48 GiB │            │
# │ 6      │ 6.52 GiB / 7.48 GiB │     40.46% │
# │ 7      │ 6.52 GiB / 7.48 GiB │            │
# └────────┴─────────────────────┴────────────┘
# Epoch 1, Step 600, Loss: 4.924214839935303, Elapsed Time: 65.45 seconds
# Generated text after batch 600:
# The story begins in the midcentury of the new season of the new series, a number of new releases, which will be released. The story was on the film and a new film that has a lot of experience, the song was the most of the album, a series, with a new songwriter. The song was the album and released the band's film and a series, the album and released on the song and released by the album. The film has played with a series, the film. The song has played with a series, the film of music. The film and song has released the song "In a series, a film.
#
# In a series of films, a film film film film film.
#
#
# A series, and film was the film.
#
# The album of The song
#
# The album of The song was published by The song and directed by The album. The song of The song is released on a series, "I think I've had the!!!!!!!
#
# TPU Chips
# ┏━━━━━━━━━━━━━┳━━━━━━━━━━━━━┳━━━━━━━━━┳━━━━━━━┓
# ┃ Chip        ┃ Type        ┃ Devices ┃ PID   ┃
# ┡━━━━━━━━━━━━━╇━━━━━━━━━━━━━╇━━━━━━━━━╇━━━━━━━┩
# │ /dev/accel0 │ TPU v2 chip │ 2       │ 55695 │
# │ /dev/accel1 │ TPU v2 chip │ 2       │ 55695 │
# │ /dev/accel2 │ TPU v2 chip │ 2       │ 55695 │
# │ /dev/accel3 │ TPU v2 chip │ 2       │ 55695 │
# └─────────────┴─────────────┴─────────┴───────┘
# Connected to libtpu at grpc://localhost:8431...
# TPU Utilization
# ┏━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┓
# ┃ Device ┃ Memory usage        ┃ Duty cycle ┃
# ┡━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━┩
# │ 0      │ 6.53 GiB / 7.48 GiB │     52.20% │
# │ 1      │ 6.52 GiB / 7.48 GiB │            │
# │ 2      │ 6.52 GiB / 7.48 GiB │     53.16% │
# │ 3      │ 6.52 GiB / 7.48 GiB │            │
# │ 4      │ 6.52 GiB / 7.48 GiB │     47.55% │
# │ 5      │ 6.52 GiB / 7.48 GiB │            │
# │ 6      │ 6.52 GiB / 7.48 GiB │     44.77% │
# │ 7      │ 6.52 GiB / 7.48 GiB │            │
# └────────┴─────────────────────┴────────────┘
# Epoch 1, Step 700, Loss: 4.79105281829834, Elapsed Time: 65.94 seconds
# Generated text after batch 700:
# The story begins in the midcentury school at the end of the weekend, I had been on a year in the last time I had a week for my last night at the school, but I had to see it was in a day, I had the time of course. I had to read this week I had a week.
# The day was I had a chance of the day, but I had been reading. I had to say, but I had my friends I had to work and my first day, and I had a great opportunity for the first time I had a week, I had a little day to get to see, and I am not the opportunity.
# The couple were so much fun. I had a few years ago I had a few of my favorite. I had to have to say that I had to have my kids. I had been thinking of that I had to do and I would be very happy with me, and I am not my parents and I had a!!!!!!!
#
# TPU Chips
# ┏━━━━━━━━━━━━━┳━━━━━━━━━━━━━┳━━━━━━━━━┳━━━━━━━┓
# ┃ Chip        ┃ Type        ┃ Devices ┃ PID   ┃
# ┡━━━━━━━━━━━━━╇━━━━━━━━━━━━━╇━━━━━━━━━╇━━━━━━━┩
# │ /dev/accel0 │ TPU v2 chip │ 2       │ 55695 │
# │ /dev/accel1 │ TPU v2 chip │ 2       │ 55695 │
# │ /dev/accel2 │ TPU v2 chip │ 2       │ 55695 │
# │ /dev/accel3 │ TPU v2 chip │ 2       │ 55695 │
# └─────────────┴─────────────┴─────────┴───────┘
# Connected to libtpu at grpc://localhost:8431...
# TPU Utilization
# ┏━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┓
# ┃ Device ┃ Memory usage        ┃ Duty cycle ┃
# ┡━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━┩
# │ 0      │ 6.53 GiB / 7.48 GiB │     58.02% │
# │ 1      │ 6.52 GiB / 7.48 GiB │            │
# │ 2      │ 6.52 GiB / 7.48 GiB │     49.29% │
# │ 3      │ 6.52 GiB / 7.48 GiB │            │
# │ 4      │ 6.52 GiB / 7.48 GiB │     49.31% │
# │ 5      │ 6.52 GiB / 7.48 GiB │            │
# │ 6      │ 6.52 GiB / 7.48 GiB │     48.84% │
# │ 7      │ 6.52 GiB / 7.48 GiB │            │
# └────────┴─────────────────────┴────────────┘
# Epoch 1, Step 800, Loss: 4.681846618652344, Elapsed Time: 64.30 seconds
# Generated text after batch 800:
# The story begins in the midcentury city, with a few months ago. The story of the new and a series is to celebrate a day, the new series is about to go on to the island. The new story of the story, is that it's the most famous story. The story is, that is not only about it. The story of the new book, which is that it's not just about it. The story of the new story of the world is not just as the first place, and is not just because the book has to be the same, and that the world's best, but the world's history has to have a long history of life. The book is that it's a very first day to see that it's a bit of a book that it is. The book, "I've always been the best and it's really great to be, but it's really really great, but I don't really feel that we are the same thing we have ever!!!!!!!
#
# TPU Chips
# ┏━━━━━━━━━━━━━┳━━━━━━━━━━━━━┳━━━━━━━━━┳━━━━━━━┓
# ┃ Chip        ┃ Type        ┃ Devices ┃ PID   ┃
# ┡━━━━━━━━━━━━━╇━━━━━━━━━━━━━╇━━━━━━━━━╇━━━━━━━┩
# │ /dev/accel0 │ TPU v2 chip │ 2       │ 55695 │
# │ /dev/accel1 │ TPU v2 chip │ 2       │ 55695 │
# │ /dev/accel2 │ TPU v2 chip │ 2       │ 55695 │
# │ /dev/accel3 │ TPU v2 chip │ 2       │ 55695 │
# └─────────────┴─────────────┴─────────┴───────┘
# Connected to libtpu at grpc://localhost:8431...
# TPU Utilization
# ┏━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┓
# ┃ Device ┃ Memory usage        ┃ Duty cycle ┃
# ┡━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━┩
# │ 0      │ 6.53 GiB / 7.48 GiB │     55.63% │
# │ 1      │ 6.52 GiB / 7.48 GiB │            │
# │ 2      │ 6.52 GiB / 7.48 GiB │     52.66% │
# │ 3      │ 6.52 GiB / 7.48 GiB │            │
# │ 4      │ 6.52 GiB / 7.48 GiB │     51.57% │
# │ 5      │ 6.52 GiB / 7.48 GiB │            │
# │ 6      │ 6.52 GiB / 7.48 GiB │     45.41% │
# │ 7      │ 6.52 GiB / 7.48 GiB │            │
# └────────┴─────────────────────┴────────────┘
# Epoch 1, Step 900, Loss: 4.602184772491455, Elapsed Time: 65.96 seconds
# Generated text after batch 900:
# The story begins in the midcentury city, a young man is the second place of the first place. The city is now open, but the most beautiful town is located in the world of the country, and it is also the first time in the country. The town is situated in the country and is one of the largest and the world in the country. The town of the country is one of the world. The town of the city has been built by the country's largest country, with its inhabitants. The town is also known as the town of the country, which has the population of the city, the country and the world of the city, is a small city. The town is also the most beautiful town of the country. The town of the town of the town of the country, a population of the world and the world is a very diverse, rich and rich in the country, the country. The population of the world has the most popular destination, which the population of the city!!!!!!!
#
# TPU Chips
# ┏━━━━━━━━━━━━━┳━━━━━━━━━━━━━┳━━━━━━━━━┳━━━━━━━┓
# ┃ Chip        ┃ Type        ┃ Devices ┃ PID   ┃
# ┡━━━━━━━━━━━━━╇━━━━━━━━━━━━━╇━━━━━━━━━╇━━━━━━━┩
# │ /dev/accel0 │ TPU v2 chip │ 2       │ 55695 │
# │ /dev/accel1 │ TPU v2 chip │ 2       │ 55695 │
# │ /dev/accel2 │ TPU v2 chip │ 2       │ 55695 │
# │ /dev/accel3 │ TPU v2 chip │ 2       │ 55695 │
# └─────────────┴─────────────┴─────────┴───────┘
# Connected to libtpu at grpc://localhost:8431...
# TPU Utilization
# ┏━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┓
# ┃ Device ┃ Memory usage        ┃ Duty cycle ┃
# ┡━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━┩
# │ 0      │ 6.53 GiB / 7.48 GiB │     52.94% │
# │ 1      │ 6.52 GiB / 7.48 GiB │            │
# │ 2      │ 6.52 GiB / 7.48 GiB │     47.33% │
# │ 3      │ 6.52 GiB / 7.48 GiB │            │
# │ 4      │ 6.52 GiB / 7.48 GiB │     46.51% │
# │ 5      │ 6.52 GiB / 7.48 GiB │            │
# │ 6      │ 6.52 GiB / 7.48 GiB │     44.79% │
# │ 7      │ 6.52 GiB / 7.48 GiB │            │
# └────────┴─────────────────────┴────────────┘
# Epoch 1, Step 1000, Loss: 4.517640590667725, Elapsed Time: 64.44 seconds
# Generated text after batch 1000:
# The story begins in the midcentury and was in the last decade. It was the second day in the summer, and then was a very little girl, I had to have the idea that he had a great chance to make the same thing as I did. It was the second year when he was in the same day, the day. It was the second year when the year, I had to have the chance of a man, but it was not much like that. It was a little time. I had the first day in the past and was in the second year, and it was not so I had the first day in the summer, and the last couple of days was in the second year, but the last time.
# The last couple of weeks ago I had been the same time in the morning. The year, the day of year was a great time and it was to me, I had the first year of my day and the day was in the day, but the first!!!!!!!
#
# TPU Chips
# ┏━━━━━━━━━━━━━┳━━━━━━━━━━━━━┳━━━━━━━━━┳━━━━━━━┓
# ┃ Chip        ┃ Type        ┃ Devices ┃ PID   ┃
# ┡━━━━━━━━━━━━━╇━━━━━━━━━━━━━╇━━━━━━━━━╇━━━━━━━┩
# │ /dev/accel0 │ TPU v2 chip │ 2       │ 55695 │
# │ /dev/accel1 │ TPU v2 chip │ 2       │ 55695 │
# │ /dev/accel2 │ TPU v2 chip │ 2       │ 55695 │
# │ /dev/accel3 │ TPU v2 chip │ 2       │ 55695 │
# └─────────────┴─────────────┴─────────┴───────┘
# Connected to libtpu at grpc://localhost:8431...
# TPU Utilization
# ┏━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┓
# ┃ Device ┃ Memory usage        ┃ Duty cycle ┃
# ┡━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━┩
# │ 0      │ 6.53 GiB / 7.48 GiB │     55.02% │
# │ 1      │ 6.52 GiB / 7.48 GiB │            │
# │ 2      │ 6.52 GiB / 7.48 GiB │     50.47% │
# │ 3      │ 6.52 GiB / 7.48 GiB │            │
# │ 4      │ 6.52 GiB / 7.48 GiB │     47.83% │
# │ 5      │ 6.52 GiB / 7.48 GiB │            │
# │ 6      │ 6.52 GiB / 7.48 GiB │     44.70% │
# │ 7      │ 6.52 GiB / 7.48 GiB │            │
# └────────┴─────────────────────┴────────────┘
# Epoch 1, Step 1100, Loss: 4.4222941398620605, Elapsed Time: 65.91 seconds
# Generated text after batch 1100:
# The story begins in the midcentury history, with a series of "the "The first" of the first time in the past two decades. The story was written in a new series, with the "the most beautiful" in the early stages, as a result in the history of the "The Great American Revolution."
# The first thing that is "The most beautiful." It is that it was the most beautiful story. It was the most famous and popular in the history, the story is, the most beautiful story. It is the story that it was the story. It is the most famous author of the story of the book "the story" in the "The first of the "the most popular, I've seen." It was the story of a series of a story that the "The War," the first place. It is a very rare, but the most powerful, "The world of the earth" that is not a matter of fact. It's the most beautiful, a!!!!!!!
#
# TPU Chips
# ┏━━━━━━━━━━━━━┳━━━━━━━━━━━━━┳━━━━━━━━━┳━━━━━━━┓
# ┃ Chip        ┃ Type        ┃ Devices ┃ PID   ┃
# ┡━━━━━━━━━━━━━╇━━━━━━━━━━━━━╇━━━━━━━━━╇━━━━━━━┩
# │ /dev/accel0 │ TPU v2 chip │ 2       │ 55695 │
# │ /dev/accel1 │ TPU v2 chip │ 2       │ 55695 │
# │ /dev/accel2 │ TPU v2 chip │ 2       │ 55695 │
# │ /dev/accel3 │ TPU v2 chip │ 2       │ 55695 │
# └─────────────┴─────────────┴─────────┴───────┘
# Connected to libtpu at grpc://localhost:8431...
# TPU Utilization
# ┏━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┓
# ┃ Device ┃ Memory usage        ┃ Duty cycle ┃
# ┡━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━┩
# │ 0      │ 6.53 GiB / 7.48 GiB │     52.97% │
# │ 1      │ 6.52 GiB / 7.48 GiB │            │
# │ 2      │ 6.52 GiB / 7.48 GiB │     48.02% │
# │ 3      │ 6.52 GiB / 7.48 GiB │            │
# │ 4      │ 6.52 GiB / 7.48 GiB │     45.89% │
# │ 5      │ 6.52 GiB / 7.48 GiB │            │
# │ 6      │ 6.52 GiB / 7.48 GiB │     43.96% │
# │ 7      │ 6.52 GiB / 7.48 GiB │            │
# └────────┴─────────────────────┴────────────┘
# Epoch 1, Step 1200, Loss: 4.34248161315918, Elapsed Time: 65.25 seconds
# Generated text after batch 1200:
# The story begins in the midcentury of the early days, with a little time to get back from the night of the season. The story begins to get the time, but it was not to have the right way. The story begins in the fall, with the rest of the day and is now a great day, but it was not the only one. The story of the first episode was on the second day. The episode is just about to see, but it is still not that it was not just the best day to come in. The episode was just the show at the show. The story is in the series. The show is in the story, the series was released by the series, which aired in the early days of the week, was a year, but it is also the only time for the first episode of the season.
# It was a day for the next time.
# It is not just about the time I had to wait until I got into the series, but!!!!!!!
#
# TPU Chips
# ┏━━━━━━━━━━━━━┳━━━━━━━━━━━━━┳━━━━━━━━━┳━━━━━━━┓
# ┃ Chip        ┃ Type        ┃ Devices ┃ PID   ┃
# ┡━━━━━━━━━━━━━╇━━━━━━━━━━━━━╇━━━━━━━━━╇━━━━━━━┩
# │ /dev/accel0 │ TPU v2 chip │ 2       │ 55695 │
# │ /dev/accel1 │ TPU v2 chip │ 2       │ 55695 │
# │ /dev/accel2 │ TPU v2 chip │ 2       │ 55695 │
# │ /dev/accel3 │ TPU v2 chip │ 2       │ 55695 │
# └─────────────┴─────────────┴─────────┴───────┘
# Connected to libtpu at grpc://localhost:8431...
# TPU Utilization
# ┏━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┓
# ┃ Device ┃ Memory usage        ┃ Duty cycle ┃
# ┡━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━┩
# │ 0      │ 6.57 GiB / 7.48 GiB │     50.69% │
# │ 1      │ 6.56 GiB / 7.48 GiB │            │
# │ 2      │ 6.56 GiB / 7.48 GiB │     47.42% │
# │ 3      │ 6.56 GiB / 7.48 GiB │            │
# │ 4      │ 6.56 GiB / 7.48 GiB │     42.75% │
# │ 5      │ 6.56 GiB / 7.48 GiB │            │
# │ 6      │ 6.56 GiB / 7.48 GiB │     42.76% │
# │ 7      │ 6.56 GiB / 7.48 GiB │            │
# └────────┴─────────────────────┴────────────┘
# Epoch 1, Step 1300, Loss: 4.281636714935303, Elapsed Time: 65.32 seconds
# Generated text after batch 1300:
# The story begins in the midcentury
# by John W. Schuacher
# In a nutshell, a new story was inspired by a young woman to discover how she is the best-selling novel.
# "It's been a part of a series of interviews that are now the best-selling novel of a life. It's the most exciting to be in a long way, the world has become the best-selling novel in a way, but I am still the first to say it is the first book, but it is not just that, but the second book of a story is that the most successful in a world-famous film is not just the best-selling novel, and is a good story of the book.
# In the past, a young man is not the only thing. The film was inspired by a story, but in a place that he has to say that he has to say, he's a very different book that has not yet to say, he has been the!!!!!!!
#
# TPU Chips
# ┏━━━━━━━━━━━━━┳━━━━━━━━━━━━━┳━━━━━━━━━┳━━━━━━━┓
# ┃ Chip        ┃ Type        ┃ Devices ┃ PID   ┃
# ┡━━━━━━━━━━━━━╇━━━━━━━━━━━━━╇━━━━━━━━━╇━━━━━━━┩
# │ /dev/accel0 │ TPU v2 chip │ 2       │ 55695 │
# │ /dev/accel1 │ TPU v2 chip │ 2       │ 55695 │
# │ /dev/accel2 │ TPU v2 chip │ 2       │ 55695 │
# │ /dev/accel3 │ TPU v2 chip │ 2       │ 55695 │
# └─────────────┴─────────────┴─────────┴───────┘
# Connected to libtpu at grpc://localhost:8431...
# TPU Utilization
# ┏━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┓
# ┃ Device ┃ Memory usage        ┃ Duty cycle ┃
# ┡━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━┩
# │ 0      │ 6.53 GiB / 7.48 GiB │     50.84% │
# │ 1      │ 6.52 GiB / 7.48 GiB │            │
# │ 2      │ 6.52 GiB / 7.48 GiB │     46.75% │
# │ 3      │ 6.52 GiB / 7.48 GiB │            │
# │ 4      │ 6.52 GiB / 7.48 GiB │     43.35% │
# │ 5      │ 6.52 GiB / 7.48 GiB │            │
# │ 6      │ 6.52 GiB / 7.48 GiB │     41.76% │
# │ 7      │ 6.52 GiB / 7.48 GiB │            │
# └────────┴─────────────────────┴────────────┘
# Epoch 1, Step 1400, Loss: 4.229319095611572, Elapsed Time: 65.51 seconds
# Generated text after batch 1400:
# The story begins in the midcentury
# by David Haine
# In a short-lived
# In the late 1980s, the city's father's son is now the most beautiful of the country. The town has a rich history and the family, a history of history and culture, the town is now known as the town. The town has been in the history of the town of the country and is a small, beautiful and long-lasting town of the country. The town has a long-lasting and beautiful, rich history of history. The town has been the only city. The town has a history, a rich history, history and culture of the country, the town, the town and the town is located on the south side of the north, and the west, the city has been in the south of the east. The town has been built for centuries, with a few of the city and the most beautiful towns of the country, and the town has a population. The town!!!!!!!
#
# TPU Chips
# ┏━━━━━━━━━━━━━┳━━━━━━━━━━━━━┳━━━━━━━━━┳━━━━━━━┓
# ┃ Chip        ┃ Type        ┃ Devices ┃ PID   ┃
# ┡━━━━━━━━━━━━━╇━━━━━━━━━━━━━╇━━━━━━━━━╇━━━━━━━┩
# │ /dev/accel0 │ TPU v2 chip │ 2       │ 55695 │
# │ /dev/accel1 │ TPU v2 chip │ 2       │ 55695 │
# │ /dev/accel2 │ TPU v2 chip │ 2       │ 55695 │
# │ /dev/accel3 │ TPU v2 chip │ 2       │ 55695 │
# └─────────────┴─────────────┴─────────┴───────┘
# Connected to libtpu at grpc://localhost:8431...
# TPU Utilization
# ┏━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┓
# ┃ Device ┃ Memory usage        ┃ Duty cycle ┃
# ┡━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━┩
# │ 0      │ 6.53 GiB / 7.48 GiB │     52.64% │
# │ 1      │ 6.52 GiB / 7.48 GiB │            │
# │ 2      │ 6.52 GiB / 7.48 GiB │     50.15% │
# │ 3      │ 6.52 GiB / 7.48 GiB │            │
# │ 4      │ 6.52 GiB / 7.48 GiB │     46.51% │
# │ 5      │ 6.52 GiB / 7.48 GiB │            │
# │ 6      │ 6.52 GiB / 7.48 GiB │     52.60% │
# │ 7      │ 6.52 GiB / 7.48 GiB │            │
# └────────┴─────────────────────┴────────────┘
# Epoch 1, Step 1500, Loss: 4.183183670043945, Elapsed Time: 65.27 seconds
# Generated text after batch 1500:
# The story begins in the midcentury and has a lot of attention in the future of life, but I don't think of it, and the stories that have a very well-known history of life, so the most popular in the world is not just as a result of a story, and a lot of love for people to do so, as a whole of course.
# It is not uncommon to see what I can expect. But the stories that you're going to see the story. The stories are a very interesting thing, but that you don't have to say, I know what it's going to do, but what it means, the stories that I can't tell is a good story, but the story of the story of a life that you are a good friend, I can't see how many of them all in the future. I think that you are in the world and are the ones who do you think that they have to be. And it is the story that I!!!!!!!
#
# TPU Chips
# ┏━━━━━━━━━━━━━┳━━━━━━━━━━━━━┳━━━━━━━━━┳━━━━━━━┓
# ┃ Chip        ┃ Type        ┃ Devices ┃ PID   ┃
# ┡━━━━━━━━━━━━━╇━━━━━━━━━━━━━╇━━━━━━━━━╇━━━━━━━┩
# │ /dev/accel0 │ TPU v2 chip │ 2       │ 55695 │
# │ /dev/accel1 │ TPU v2 chip │ 2       │ 55695 │
# │ /dev/accel2 │ TPU v2 chip │ 2       │ 55695 │
# │ /dev/accel3 │ TPU v2 chip │ 2       │ 55695 │
# └─────────────┴─────────────┴─────────┴───────┘
# Connected to libtpu at grpc://localhost:8431...
# TPU Utilization
# ┏━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┓
# ┃ Device ┃ Memory usage        ┃ Duty cycle ┃
# ┡━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━┩
# │ 0      │ 6.53 GiB / 7.48 GiB │     51.27% │
# │ 1      │ 6.52 GiB / 7.48 GiB │            │
# │ 2      │ 6.52 GiB / 7.48 GiB │     49.83% │
# │ 3      │ 6.52 GiB / 7.48 GiB │            │
# │ 4      │ 6.52 GiB / 7.48 GiB │     43.63% │
# │ 5      │ 6.52 GiB / 7.48 GiB │            │
# │ 6      │ 6.52 GiB / 7.48 GiB │     41.07% │
# │ 7      │ 6.52 GiB / 7.48 GiB │            │
# └────────┴─────────────────────┴────────────┘
# Epoch 1, Step 1600, Loss: 4.14777135848999, Elapsed Time: 63.76 seconds
# Generated text after batch 1600:
# The story begins in the midcentury and has been in the midst of a very short time of life. It was the perfect place to enjoy a day-to-day holiday in the summer of summer. The family was born and raised in the late-night of the year and had been raised by the families of the children of the ages. The children of the ages are not a little more, but also have the chance to spend the holiday season and get back in the year. The parents were not the kids of the school and their children, they are still very much in the early years of life. The kids are also in the middle of the age of their parents, their children and parents were not a family, and their parents are still the parents who were able to stay on the family. The kids were very excited about the family of their children, their children and parents, their children and parents. The parents are not just the parents who have the kids who have the kids in the!!!!!!!
#
# TPU Chips
# ┏━━━━━━━━━━━━━┳━━━━━━━━━━━━━┳━━━━━━━━━┳━━━━━━━┓
# ┃ Chip        ┃ Type        ┃ Devices ┃ PID   ┃
# ┡━━━━━━━━━━━━━╇━━━━━━━━━━━━━╇━━━━━━━━━╇━━━━━━━┩
# │ /dev/accel0 │ TPU v2 chip │ 2       │ 55695 │
# │ /dev/accel1 │ TPU v2 chip │ 2       │ 55695 │
# │ /dev/accel2 │ TPU v2 chip │ 2       │ 55695 │
# │ /dev/accel3 │ TPU v2 chip │ 2       │ 55695 │
# └─────────────┴─────────────┴─────────┴───────┘
# Connected to libtpu at grpc://localhost:8431...
# TPU Utilization
# ┏━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┓
# ┃ Device ┃ Memory usage        ┃ Duty cycle ┃
# ┡━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━┩
# │ 0      │ 6.53 GiB / 7.48 GiB │     52.75% │
# │ 1      │ 6.52 GiB / 7.48 GiB │            │
# │ 2      │ 6.52 GiB / 7.48 GiB │     46.83% │
# │ 3      │ 6.52 GiB / 7.48 GiB │            │
# │ 4      │ 6.52 GiB / 7.48 GiB │     45.87% │
# │ 5      │ 6.52 GiB / 7.48 GiB │            │
# │ 6      │ 6.52 GiB / 7.48 GiB │     46.78% │
# │ 7      │ 6.52 GiB / 7.48 GiB │            │
# └────────┴─────────────────────┴────────────┘
# Epoch 1, Step 1700, Loss: 4.114998817443848, Elapsed Time: 64.78 seconds
# Generated text after batch 1700:
# The story begins in the midcentury period, and it was not only one of the most common things I had ever heard. I had been to know that it was so far from that.
# The story was about a lot of people and had been told. It was the one of the world's most powerful and powerful stories of people, but the world has become more of a life-changing and powerful and creative world.
# It is not just about a story that has become more difficult and powerful. I believe this is the world of a great, but the world has a rich, powerful and diverse and vibrant culture, so I am glad that the world has always been the most of us.
# It's not that we're the only person of the world who can have to say about it, and we have the best experience in our life.
# We're always looking forward to the journey. We have the most amazing experiences and passion to get you excited and have a lot of things in!!!!!!!
#
# TPU Chips
# ┏━━━━━━━━━━━━━┳━━━━━━━━━━━━━┳━━━━━━━━━┳━━━━━━━┓
# ┃ Chip        ┃ Type        ┃ Devices ┃ PID   ┃
# ┡━━━━━━━━━━━━━╇━━━━━━━━━━━━━╇━━━━━━━━━╇━━━━━━━┩
# │ /dev/accel0 │ TPU v2 chip │ 2       │ 55695 │
# │ /dev/accel1 │ TPU v2 chip │ 2       │ 55695 │
# │ /dev/accel2 │ TPU v2 chip │ 2       │ 55695 │
# │ /dev/accel3 │ TPU v2 chip │ 2       │ 55695 │
# └─────────────┴─────────────┴─────────┴───────┘
# Connected to libtpu at grpc://localhost:8431...
# TPU Utilization
# ┏━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┓
# ┃ Device ┃ Memory usage        ┃ Duty cycle ┃
# ┡━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━┩
# │ 0      │ 6.53 GiB / 7.48 GiB │     53.64% │
# │ 1      │ 6.52 GiB / 7.48 GiB │            │
# │ 2      │ 6.52 GiB / 7.48 GiB │     52.83% │
# │ 3      │ 6.52 GiB / 7.48 GiB │            │
# │ 4      │ 6.52 GiB / 7.48 GiB │     50.00% │
# │ 5      │ 6.52 GiB / 7.48 GiB │            │
# │ 6      │ 6.52 GiB / 7.48 GiB │     46.50% │
# │ 7      │ 6.52 GiB / 7.48 GiB │            │
# └────────┴─────────────────────┴────────────┘
# Epoch 1, Step 1800, Loss: 4.089474201202393, Elapsed Time: 63.39 seconds
# Generated text after batch 1800:
# The story begins in the midcentury and has a new era of "the story" of a young woman in the world of a young woman. The story is also the first woman in the heart of a young woman. The story begins at 6:00 a.m.
# The story is the first woman to join her. She has a great deal to find out about her story. She has been the best part of her life, but she is also a member of her life. She is also the first woman in the heart of her father, who has a long history. She has been the best time she is in her life, but her mother has never been.
# Her life has always been in her life, but her father has a wealth of life, but her father is also her family.
# The story begins at 8:00 p.m. and has her father, the family is the father of a child, and she has her mother, her family. She has!!!!!!!
#
# TPU Chips
# ┏━━━━━━━━━━━━━┳━━━━━━━━━━━━━┳━━━━━━━━━┳━━━━━━━┓
# ┃ Chip        ┃ Type        ┃ Devices ┃ PID   ┃
# ┡━━━━━━━━━━━━━╇━━━━━━━━━━━━━╇━━━━━━━━━╇━━━━━━━┩
# │ /dev/accel0 │ TPU v2 chip │ 2       │ 55695 │
# │ /dev/accel1 │ TPU v2 chip │ 2       │ 55695 │
# │ /dev/accel2 │ TPU v2 chip │ 2       │ 55695 │
# │ /dev/accel3 │ TPU v2 chip │ 2       │ 55695 │
# └─────────────┴─────────────┴─────────┴───────┘
# Connected to libtpu at grpc://localhost:8431...
# TPU Utilization
# ┏━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┓
# ┃ Device ┃ Memory usage        ┃ Duty cycle ┃
# ┡━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━┩
# │ 0      │ 6.53 GiB / 7.48 GiB │     51.69% │
# │ 1      │ 6.52 GiB / 7.48 GiB │            │
# │ 2      │ 6.52 GiB / 7.48 GiB │     45.32% │
# │ 3      │ 6.52 GiB / 7.48 GiB │            │
# │ 4      │ 6.52 GiB / 7.48 GiB │     43.78% │
# │ 5      │ 6.52 GiB / 7.48 GiB │            │
# │ 6      │ 6.52 GiB / 7.48 GiB │     41.62% │
# │ 7      │ 6.52 GiB / 7.48 GiB │            │
# └────────┴─────────────────────┴────────────┘
# Epoch 1, Step 1900, Loss: 4.062629222869873, Elapsed Time: 64.25 seconds
# Generated text after batch 1900:
# The story begins in the midcentury and the family has been about the same.
# It's not just about the time. It's about how to start it and how to get the money, and what it is to get it to you, but the time it is to start the process of a day.
# I think that it is the most important part of this book, and that I know it's a little different from the time I have.
# It's about to start a journey that you have to go into a little bit.
# The first step is to make the first step of the process, but the second step is to take a look.
# I'm a fan of the game and it's not just a lot.
# It's not the way you get it to do this, but the second time it is the best thing.
# The second part of the first half of the series is that you are looking to start the next one.
# I've done it.!!!!!!!
#
# TPU Chips
# ┏━━━━━━━━━━━━━┳━━━━━━━━━━━━━┳━━━━━━━━━┳━━━━━━━┓
# ┃ Chip        ┃ Type        ┃ Devices ┃ PID   ┃
# ┡━━━━━━━━━━━━━╇━━━━━━━━━━━━━╇━━━━━━━━━╇━━━━━━━┩
# │ /dev/accel0 │ TPU v2 chip │ 2       │ 55695 │
# │ /dev/accel1 │ TPU v2 chip │ 2       │ 55695 │
# │ /dev/accel2 │ TPU v2 chip │ 2       │ 55695 │
# │ /dev/accel3 │ TPU v2 chip │ 2       │ 55695 │
# └─────────────┴─────────────┴─────────┴───────┘
# Connected to libtpu at grpc://localhost:8431...
# TPU Utilization
# ┏━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┓
# ┃ Device ┃ Memory usage        ┃ Duty cycle ┃
# ┡━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━┩
# │ 0      │ 6.53 GiB / 7.48 GiB │     56.62% │
# │ 1      │ 6.52 GiB / 7.48 GiB │            │
# │ 2      │ 6.52 GiB / 7.48 GiB │     52.76% │
# │ 3      │ 6.52 GiB / 7.48 GiB │            │
# │ 4      │ 6.52 GiB / 7.48 GiB │     46.89% │
# │ 5      │ 6.52 GiB / 7.48 GiB │            │
# │ 6      │ 6.52 GiB / 7.48 GiB │     49.00% │
# │ 7      │ 6.52 GiB / 7.48 GiB │            │
# └────────┴─────────────────────┴────────────┘
# Epoch 1, Step 2000, Loss: 4.032273769378662, Elapsed Time: 64.16 seconds
# Generated text after batch 2000:
# The story begins in the midcentury era of the world, the two most successful film series has become the biggest ever-expanding and successful film ever. It is the story of the series of the most popular films and movies.
# The story starts at 9:00 a.m.
# The story starts in the mid-1960s. The story starts by a mysterious woman, who finds the story.
# The film stars, the first movie is set in the second year. The movie has a long-time record in the early 1970s, which has a number of movies. The movie has been written in the series of movies, films and TV series. The film has been directed by The Times of The Star Wars, and has released the series on Netflix, and it is a sequel.
# The movie stars have a series of movies that will play a film on Netflix.
# The movie is based on the movie's journey from the movie.
# The film is set to take the!!!!!!!
#
# TPU Chips
# ┏━━━━━━━━━━━━━┳━━━━━━━━━━━━━┳━━━━━━━━━┳━━━━━━━┓
# ┃ Chip        ┃ Type        ┃ Devices ┃ PID   ┃
# ┡━━━━━━━━━━━━━╇━━━━━━━━━━━━━╇━━━━━━━━━╇━━━━━━━┩
# │ /dev/accel0 │ TPU v2 chip │ 2       │ 55695 │
# │ /dev/accel1 │ TPU v2 chip │ 2       │ 55695 │
# │ /dev/accel2 │ TPU v2 chip │ 2       │ 55695 │
# │ /dev/accel3 │ TPU v2 chip │ 2       │ 55695 │
# └─────────────┴─────────────┴─────────┴───────┘
# Connected to libtpu at grpc://localhost:8431...
# TPU Utilization
# ┏━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┓
# ┃ Device ┃ Memory usage        ┃ Duty cycle ┃
# ┡━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━┩
# │ 0      │ 6.53 GiB / 7.48 GiB │     49.79% │
# │ 1      │ 6.52 GiB / 7.48 GiB │            │
# │ 2      │ 6.52 GiB / 7.48 GiB │     46.43% │
# │ 3      │ 6.52 GiB / 7.48 GiB │            │
# │ 4      │ 6.52 GiB / 7.48 GiB │     43.88% │
# │ 5      │ 6.52 GiB / 7.48 GiB │            │
# │ 6      │ 6.52 GiB / 7.48 GiB │     43.15% │
# │ 7      │ 6.52 GiB / 7.48 GiB │            │
# └────────┴─────────────────────┴────────────┘
# Epoch 1, Step 2100, Loss: 4.0144572257995605, Elapsed Time: 63.86 seconds
# Generated text after batch 2100:
# The story begins in the midcentury town of Diaquez. The story begins at a small village of Diaquez, where he was about to see a young girl and the girl's name is. The story begins in the mid century.
# A man's life begins in the late 1950s and the family's death, a mother and her husband. The father, who was a man who lived in the middle of the family and a father of three years ago, is in the middle of his life. The story begins at a small village in Diaquez, a mother of a father. The story begins in the middle of his life and was about to have the son of the family and father of a mother of the mother of a father of the family. The mother, a son, father of a family and mother of a father of the mother, and father of the father, the son of a family and the family of a mother of his family. The father!!!!!!!
#
# TPU Chips
# ┏━━━━━━━━━━━━━┳━━━━━━━━━━━━━┳━━━━━━━━━┳━━━━━━━┓
# ┃ Chip        ┃ Type        ┃ Devices ┃ PID   ┃
# ┡━━━━━━━━━━━━━╇━━━━━━━━━━━━━╇━━━━━━━━━╇━━━━━━━┩
# │ /dev/accel0 │ TPU v2 chip │ 2       │ 55695 │
# │ /dev/accel1 │ TPU v2 chip │ 2       │ 55695 │
# │ /dev/accel2 │ TPU v2 chip │ 2       │ 55695 │
# │ /dev/accel3 │ TPU v2 chip │ 2       │ 55695 │
# └─────────────┴─────────────┴─────────┴───────┘
# Connected to libtpu at grpc://localhost:8431...
# TPU Utilization
# ┏━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┓
# ┃ Device ┃ Memory usage        ┃ Duty cycle ┃
# ┡━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━┩
# │ 0      │ 6.57 GiB / 7.48 GiB │     52.34% │
# │ 1      │ 6.56 GiB / 7.48 GiB │            │
# │ 2      │ 6.56 GiB / 7.48 GiB │     48.43% │
# │ 3      │ 6.56 GiB / 7.48 GiB │            │
# │ 4      │ 6.56 GiB / 7.48 GiB │     47.21% │
# │ 5      │ 6.56 GiB / 7.48 GiB │            │
# │ 6      │ 6.56 GiB / 7.48 GiB │     44.77% │
# │ 7      │ 6.56 GiB / 7.48 GiB │            │
# └────────┴─────────────────────┴────────────┘
# Epoch 1, Step 2200, Loss: 3.998234510421753, Elapsed Time: 65.31 seconds
# Generated text after batch 2200:
# The story begins in the midcentury history of the United States.
# The story begins on Monday, June 17, 2014, and was written by the author, "The book of the Book of the Year." The story begins with a mysterious new chapter in the story, the book of the American Historical Society of America's National Library, which was published by the author, and was written by the author, and was also published in the journal of the Book of the American Historical Society of America.
#
# History
#
# History
#
# History
#
#
# The book is the book, a novel by the American Historical Society of America's National Library of America's National Library, which was published by the National Library, was published by the American Library of America, the Library, the National Library of America.
#
# The story is written by the author, a literary journal of American History and published by the American Historical Society, the American Library of America's National Library of America. The books, a!!!!!!!
#
# TPU Chips
# ┏━━━━━━━━━━━━━┳━━━━━━━━━━━━━┳━━━━━━━━━┳━━━━━━━┓
# ┃ Chip        ┃ Type        ┃ Devices ┃ PID   ┃
# ┡━━━━━━━━━━━━━╇━━━━━━━━━━━━━╇━━━━━━━━━╇━━━━━━━┩
# │ /dev/accel0 │ TPU v2 chip │ 2       │ 55695 │
# │ /dev/accel1 │ TPU v2 chip │ 2       │ 55695 │
# │ /dev/accel2 │ TPU v2 chip │ 2       │ 55695 │
# │ /dev/accel3 │ TPU v2 chip │ 2       │ 55695 │
# └─────────────┴─────────────┴─────────┴───────┘
# Connected to libtpu at grpc://localhost:8431...
# TPU Utilization
# ┏━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┓
# ┃ Device ┃ Memory usage        ┃ Duty cycle ┃
# ┡━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━┩
# │ 0      │ 6.53 GiB / 7.48 GiB │     54.78% │
# │ 1      │ 6.52 GiB / 7.48 GiB │            │
# │ 2      │ 6.52 GiB / 7.48 GiB │     51.61% │
# │ 3      │ 6.52 GiB / 7.48 GiB │            │
# │ 4      │ 6.52 GiB / 7.48 GiB │     46.48% │
# │ 5      │ 6.52 GiB / 7.48 GiB │            │
# │ 6      │ 6.52 GiB / 7.48 GiB │     47.17% │
# │ 7      │ 6.52 GiB / 7.48 GiB │            │
# └────────┴─────────────────────┴────────────┘
# Epoch 1, Step 2300, Loss: 3.980743646621704, Elapsed Time: 64.73 seconds
# Generated text after batch 2300:
# The story begins in the midcentury and the beginning of the era.
# A series of novels that were written in the book and the story begins with the introduction of a story of the story of a new story of the novel, a book published by the American Book Society, the book's author and a story.
# A series of books published in the books published by the American Book Society. The books were published in the books of the books and published in the books and the book are written in the books. The books and the book have been published in the book. The books, published in the books, books and books and books of the books and books. The book's book and book books and book chapters have been published in the book. The book, The book and The book and the books and book, and The books and the book and book chapters. The book, and The books and The book and books are written in the book and the books.
# The book is a!!!!!!!
#
# TPU Chips
# ┏━━━━━━━━━━━━━┳━━━━━━━━━━━━━┳━━━━━━━━━┳━━━━━━━┓
# ┃ Chip        ┃ Type        ┃ Devices ┃ PID   ┃
# ┡━━━━━━━━━━━━━╇━━━━━━━━━━━━━╇━━━━━━━━━╇━━━━━━━┩
# │ /dev/accel0 │ TPU v2 chip │ 2       │ 55695 │
# │ /dev/accel1 │ TPU v2 chip │ 2       │ 55695 │
# │ /dev/accel2 │ TPU v2 chip │ 2       │ 55695 │
# │ /dev/accel3 │ TPU v2 chip │ 2       │ 55695 │
# └─────────────┴─────────────┴─────────┴───────┘
# Connected to libtpu at grpc://localhost:8431...
# TPU Utilization
# ┏━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┓
# ┃ Device ┃ Memory usage        ┃ Duty cycle ┃
# ┡━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━┩
# │ 0      │ 6.53 GiB / 7.48 GiB │     50.83% │
# │ 1      │ 6.52 GiB / 7.48 GiB │            │
# │ 2      │ 6.52 GiB / 7.48 GiB │     52.39% │
# │ 3      │ 6.52 GiB / 7.48 GiB │            │
# │ 4      │ 6.52 GiB / 7.48 GiB │     49.14% │
# │ 5      │ 6.52 GiB / 7.48 GiB │            │
# │ 6      │ 6.52 GiB / 7.48 GiB │     46.26% │
# │ 7      │ 6.52 GiB / 7.48 GiB │            │
# └────────┴─────────────────────┴────────────┘
# Epoch 1, Step 2400, Loss: 3.95751953125, Elapsed Time: 63.90 seconds
# Generated text after batch 2400:
# The story begins in the midcentury, but is still about to come to a surprise that we've had the pleasure of having the same day in the summer. The story is not a bit about it. The story begins with the idea of a friend and I've seen a few days later. The story begins, with a lot of the stories I have had been doing for years, but it is a lot of people who are not so busy and very often, with a little bit of time, it is just about the story itself. The story begins in the mid-1800s and the story starts from a bit about a lot of time, but I've been reading it in my own life. The story starts, with the stories I have seen. The story starts in the mid-1970s and was written in the middle of the day.
# I have to be honest with my thoughts on this, but it is the time to start the day, but the stories of my life will!!!!!!!
#
# TPU Chips
# ┏━━━━━━━━━━━━━┳━━━━━━━━━━━━━┳━━━━━━━━━┳━━━━━━━┓
# ┃ Chip        ┃ Type        ┃ Devices ┃ PID   ┃
# ...
# In this book, we'll be exploring the ways of war that have led to the death of a war that was later on in the war, which will be a time that was not the end of war. We'll also learn that war has led to war. We'll be exploring the ways of war and how it is done, but that is what it takes to make the war a place where war has been waged and is the beginning of war. We'll also learn about the war, how it will take us to war and how it will unfold!!!!!!!
#
# TPU Chips
# ┏━━━━━━━━━━━━━┳━━━━━━━━━━━━━┳━━━━━━━━━┳━━━━━━━┓
# ┃ Chip        ┃ Type        ┃ Devices ┃ PID   ┃
# ┡━━━━━━━━━━━━━╇━━━━━━━━━━━━━╇━━━━━━━━━╇━━━━━━━┩
# │ /dev/accel0 │ TPU v2 chip │ 2       │ 83957 │
# │ /dev/accel1 │ TPU v2 chip │ 2       │ 83957 │
# │ /dev/accel2 │ TPU v2 chip │ 2       │ 83957 │
# │ /dev/accel3 │ TPU v2 chip │ 2       │ 83957 │
# └─────────────┴─────────────┴─────────┴───────┘
# Connected to libtpu at grpc://localhost:8431...
# TPU Utilization
# ┏━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┓
# ┃ Device ┃ Memory usage        ┃ Duty cycle ┃
# ┡━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━┩
# │ 0      │ 6.60 GiB / 7.48 GiB │     53.67% │
# │ 1      │ 6.60 GiB / 7.48 GiB │            │
# │ 2      │ 6.60 GiB / 7.48 GiB │     48.98% │
# │ 3      │ 6.60 GiB / 7.48 GiB │            │
# │ 4      │ 6.60 GiB / 7.48 GiB │     46.57% │
# │ 5      │ 6.60 GiB / 7.48 GiB │            │
# │ 6      │ 6.60 GiB / 7.48 GiB │     44.14% │
# │ 7      │ 6.60 GiB / 7.48 GiB │            │
# └────────┴─────────────────────┴────────────┘
# Epoch 2, Step 8500, Loss: 3.4960598945617676, Elapsed Time: 65.28 seconds
# Generated text after batch 8500:
# The story begins in the midcentury of the American Civil War, where it is, of course, a very common and important battle for the war, of course, in which it was the war that was fought between the American people. The American Civil War, the first in its history, and the second war that lasted for two years. The story begins in the midcentury.
#
# History
#
# In 1869, the United States, the United States, and the United States were divided between the American Civil War and the American Civil War. In 1875, the United States, the United States and the United States, were divided into the American Civil War, the United States, and the United States, and the United States, and the United States, and the United States, and the United States, and the United States, and the United States. The United States, the United States, and the United States, were divided into two groups.
#
# In 1876, the United!!!!!!!
#
# TPU Chips
# ┏━━━━━━━━━━━━━┳━━━━━━━━━━━━━┳━━━━━━━━━┳━━━━━━━┓
# ┃ Chip        ┃ Type        ┃ Devices ┃ PID   ┃
# ┡━━━━━━━━━━━━━╇━━━━━━━━━━━━━╇━━━━━━━━━╇━━━━━━━┩
# │ /dev/accel0 │ TPU v2 chip │ 2       │ 83957 │
# │ /dev/accel1 │ TPU v2 chip │ 2       │ 83957 │
# │ /dev/accel2 │ TPU v2 chip │ 2       │ 83957 │
# │ /dev/accel3 │ TPU v2 chip │ 2       │ 83957 │
# └─────────────┴─────────────┴─────────┴───────┘
# Connected to libtpu at grpc://localhost:8431...
# TPU Utilization
# ┏━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┓
# ┃ Device ┃ Memory usage        ┃ Duty cycle ┃
# ┡━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━┩
# │ 0      │ 6.53 GiB / 7.48 GiB │     54.03% │
# │ 1      │ 6.53 GiB / 7.48 GiB │            │
# │ 2      │ 6.53 GiB / 7.48 GiB │     48.41% │
# │ 3      │ 6.53 GiB / 7.48 GiB │            │
# │ 4      │ 6.53 GiB / 7.48 GiB │     45.63% │
# │ 5      │ 6.53 GiB / 7.48 GiB │            │
# │ 6      │ 6.53 GiB / 7.48 GiB │     44.53% │
# │ 7      │ 6.53 GiB / 7.48 GiB │            │
# └────────┴─────────────────────┴────────────┘
# Epoch 2, Step 8600, Loss: 3.498892068862915, Elapsed Time: 65.32 seconds
# Generated text after batch 8600:
# The story begins in the midcentury of the American Civil War, with a story about a woman who is the subject of the war and a man who has the courage to be found. The story begins in the early 1920s, when a woman who is the woman who was shot and killed a man in the mid-19th century.
# In the mid-1920s, the story begins in the early 1920s. In the mid-19s, the woman was killed by a woman who was shot and killed in the early 1930s. In the mid-19s, the woman was shot and killed in the mid-1920s. In the early 1920s, the woman was shot and killed by a woman in the early 1920s. The woman was shot and killed by a man who was shot and killed in the mid-19s. In the early 1930s, the woman was shot and killed by a man in the early 1920s. The woman was shot and killed by!!!!!!!
#
# TPU Chips
# ┏━━━━━━━━━━━━━┳━━━━━━━━━━━━━┳━━━━━━━━━┳━━━━━━━┓
# ┃ Chip        ┃ Type        ┃ Devices ┃ PID   ┃
# ┡━━━━━━━━━━━━━╇━━━━━━━━━━━━━╇━━━━━━━━━╇━━━━━━━┩
# │ /dev/accel0 │ TPU v2 chip │ 2       │ 83957 │
# │ /dev/accel1 │ TPU v2 chip │ 2       │ 83957 │
# │ /dev/accel2 │ TPU v2 chip │ 2       │ 83957 │
# │ /dev/accel3 │ TPU v2 chip │ 2       │ 83957 │
# └─────────────┴─────────────┴─────────┴───────┘
# Connected to libtpu at grpc://localhost:8431...
# TPU Utilization
# ┏━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┓
# ┃ Device ┃ Memory usage        ┃ Duty cycle ┃
# ┡━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━┩
# │ 0      │ 6.53 GiB / 7.48 GiB │     51.88% │
# │ 1      │ 6.52 GiB / 7.48 GiB │            │
# │ 2      │ 6.52 GiB / 7.48 GiB │     50.48% │
# │ 3      │ 6.52 GiB / 7.48 GiB │            │
# │ 4      │ 6.52 GiB / 7.48 GiB │     45.68% │
# │ 5      │ 6.52 GiB / 7.48 GiB │            │
# │ 6      │ 6.52 GiB / 7.48 GiB │     42.83% │
# │ 7      │ 6.52 GiB / 7.48 GiB │            │
# └────────┴─────────────────────┴────────────┘
# Epoch 2, Step 8700, Loss: 3.4988691806793213, Elapsed Time: 64.26 seconds
# Generated text after batch 8700:
# The story begins in the midcentury of the American Civil War, with a story about a woman who is the subject of the war and a man who has the courage to take it out. The story begins in the early 1920s, in which she is forced to leave, the woman who has the courage to go on the path to death, the woman who is the subject of the war, and the woman who has the courage to take it out. The story begins in the early 1920s and ends in the midcentury, and ends in the midcentury, when she meets the young man, and ends in the midcentury, and when she meets the young man who has the courage to take it out. The story begins in the early 1920s and ends in the early 1930s.
# In the midcentury, the story begins in the early 1930s, with a small town called "a town" (and later, a city of about three thousand inhabitants) and in the midcentury!!!!!!!
#
# TPU Chips
# ┏━━━━━━━━━━━━━┳━━━━━━━━━━━━━┳━━━━━━━━━┳━━━━━━━┓
# ┃ Chip        ┃ Type        ┃ Devices ┃ PID   ┃
# ┡━━━━━━━━━━━━━╇━━━━━━━━━━━━━╇━━━━━━━━━╇━━━━━━━┩
# │ /dev/accel0 │ TPU v2 chip │ 2       │ 83957 │
# │ /dev/accel1 │ TPU v2 chip │ 2       │ 83957 │
# │ /dev/accel2 │ TPU v2 chip │ 2       │ 83957 │
# │ /dev/accel3 │ TPU v2 chip │ 2       │ 83957 │
# └─────────────┴─────────────┴─────────┴───────┘
# Connected to libtpu at grpc://localhost:8431...
# TPU Utilization
# ┏━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┓
# ┃ Device ┃ Memory usage        ┃ Duty cycle ┃
# ┡━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━┩
# │ 0      │ 6.53 GiB / 7.48 GiB │     50.11% │
# │ 1      │ 6.52 GiB / 7.48 GiB │            │
# │ 2      │ 6.52 GiB / 7.48 GiB │     46.17% │
# │ 3      │ 6.52 GiB / 7.48 GiB │            │
# │ 4      │ 6.52 GiB / 7.48 GiB │     46.52% │
# │ 5      │ 6.52 GiB / 7.48 GiB │            │
# │ 6      │ 6.52 GiB / 7.48 GiB │     41.42% │
# │ 7      │ 6.52 GiB / 7.48 GiB │            │
# └────────┴─────────────────────┴────────────┘
# Epoch 2, Step 8800, Loss: 3.497746467590332, Elapsed Time: 63.77 seconds
# Generated text after batch 8800:
# The story begins in the midcentury of the American Civil War, with a story about a man who is the subject of the war and a woman who has the courage to fight for a woman who has a great love of life. The story begins in the early 1700s, in which a man is forced to confront a man who is a woman who is the subject of a man who is the subject of a woman who has a great love of life. The story begins in the early 1700s and ends in the midcentury, and the story begins in the midcentury.
# In the midcentury, the story begins in the early 1800s, and ends in the early 1800s, when the war was ended, and the war ended in the midcentury.
# In the early 1700s, the war ended in the early 1800s, when the war began. In the midcentury, the war was eventually ended, and the war began in the early 1800s.
# The war ended in!!!!!!!
#
# TPU Chips
# ┏━━━━━━━━━━━━━┳━━━━━━━━━━━━━┳━━━━━━━━━┳━━━━━━━┓
# ┃ Chip        ┃ Type        ┃ Devices ┃ PID   ┃
# ┡━━━━━━━━━━━━━╇━━━━━━━━━━━━━╇━━━━━━━━━╇━━━━━━━┩
# │ /dev/accel0 │ TPU v2 chip │ 2       │ 83957 │
# │ /dev/accel1 │ TPU v2 chip │ 2       │ 83957 │
# │ /dev/accel2 │ TPU v2 chip │ 2       │ 83957 │
# │ /dev/accel3 │ TPU v2 chip │ 2       │ 83957 │
# └─────────────┴─────────────┴─────────┴───────┘
# Connected to libtpu at grpc://localhost:8431...
# TPU Utilization
# ┏━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┓
# ┃ Device ┃ Memory usage        ┃ Duty cycle ┃
# ┡━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━┩
# │ 0      │ 6.53 GiB / 7.48 GiB │     51.24% │
# │ 1      │ 6.52 GiB / 7.48 GiB │            │
# │ 2      │ 6.52 GiB / 7.48 GiB │     48.20% │
# │ 3      │ 6.52 GiB / 7.48 GiB │            │
# │ 4      │ 6.52 GiB / 7.48 GiB │     46.59% │
# │ 5      │ 6.52 GiB / 7.48 GiB │            │
# │ 6      │ 6.52 GiB / 7.48 GiB │     45.22% │
# │ 7      │ 6.52 GiB / 7.48 GiB │            │
# └────────┴─────────────────────┴────────────┘
# Epoch 2, Step 8900, Loss: 3.4908206462860107, Elapsed Time: 64.31 seconds
# Generated text after batch 8900:
# The story begins in the midcentury of the American Civil War, with a story about a man who is the subject of the war and a woman who has died of a stroke in the middle of the night. The story begins in the early 1800s, in which a woman is murdered.
# In the midcentury, a man is a woman who has died of a stroke. In the midcentury, the man was born to a young man, a woman who is the subject of the war and a woman who is a victim of a stroke. In the early 1900s, a man is the subject of a death, a man is a man who is the subject of the war and a woman is the subject of the war. In the early 1920s, the man was born in the United States and died in the midcentury. In the midcentury, a man is a man who is a woman who has died of a stroke.
# The story begins in the early 1800s. In!!!!!!!
#
# TPU Chips
# ┏━━━━━━━━━━━━━┳━━━━━━━━━━━━━┳━━━━━━━━━┳━━━━━━━┓
# ┃ Chip        ┃ Type        ┃ Devices ┃ PID   ┃
# ┡━━━━━━━━━━━━━╇━━━━━━━━━━━━━╇━━━━━━━━━╇━━━━━━━┩
# │ /dev/accel0 │ TPU v2 chip │ 2       │ 83957 │
# │ /dev/accel1 │ TPU v2 chip │ 2       │ 83957 │
# │ /dev/accel2 │ TPU v2 chip │ 2       │ 83957 │
# │ /dev/accel3 │ TPU v2 chip │ 2       │ 83957 │
# └─────────────┴─────────────┴─────────┴───────┘
# Connected to libtpu at grpc://localhost:8431...
# TPU Utilization
# ┏━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┓
# ┃ Device ┃ Memory usage        ┃ Duty cycle ┃
# ┡━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━┩
# │ 0      │ 6.53 GiB / 7.48 GiB │     52.52% │
# │ 1      │ 6.53 GiB / 7.48 GiB │            │
# │ 2      │ 6.53 GiB / 7.48 GiB │     47.93% │
# │ 3      │ 6.53 GiB / 7.48 GiB │            │
# │ 4      │ 6.53 GiB / 7.48 GiB │     44.74% │
# │ 5      │ 6.53 GiB / 7.48 GiB │            │
# │ 6      │ 6.53 GiB / 7.48 GiB │     43.98% │
# │ 7      │ 6.53 GiB / 7.48 GiB │            │
# └────────┴─────────────────────┴────────────┘
# Epoch 2, Step 9000, Loss: 3.4967992305755615, Elapsed Time: 64.95 seconds
# Generated text after batch 9000:
# The story begins in the midcentury of the American Civil War, with a focus on the war, the American Civil War and the Civil War. The story begins in the early 20th century and the first time that the United States and the American Civil War had begun in 1848, when the American Civil War had been established, the American Civil War, the United States, and the first American Civil War, was fought on the U.S. Army, the American Civil War and the Civil War, and the First Continental War was the first American to be executed by the United States, the United States and the United States. The first American Civil War was the American Civil War. The American Civil War, with the American Civil War, with the United States and the First Continental War, was fought on the U.S. and American Civil War. The first American Civil War was the first American to be executed by the United States, and the United States and the First Continental War. The American!!!!!!!
#
# TPU Chips
# ┏━━━━━━━━━━━━━┳━━━━━━━━━━━━━┳━━━━━━━━━┳━━━━━━━┓
# ┃ Chip        ┃ Type        ┃ Devices ┃ PID   ┃
# ┡━━━━━━━━━━━━━╇━━━━━━━━━━━━━╇━━━━━━━━━╇━━━━━━━┩
# │ /dev/accel0 │ TPU v2 chip │ 2       │ 83957 │
# │ /dev/accel1 │ TPU v2 chip │ 2       │ 83957 │
# │ /dev/accel2 │ TPU v2 chip │ 2       │ 83957 │
# │ /dev/accel3 │ TPU v2 chip │ 2       │ 83957 │
# └─────────────┴─────────────┴─────────┴───────┘
# Connected to libtpu at grpc://localhost:8431...
# TPU Utilization
# ┏━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┓
# ┃ Device ┃ Memory usage        ┃ Duty cycle ┃
# ┡━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━┩
# │ 0      │ 6.53 GiB / 7.48 GiB │     53.41% │
# │ 1      │ 6.53 GiB / 7.48 GiB │            │
# │ 2      │ 6.53 GiB / 7.48 GiB │     49.87% │
# │ 3      │ 6.53 GiB / 7.48 GiB │            │
# │ 4      │ 6.53 GiB / 7.48 GiB │     45.84% │
# │ 5      │ 6.53 GiB / 7.48 GiB │            │
# │ 6      │ 6.53 GiB / 7.48 GiB │     44.95% │
# │ 7      │ 6.53 GiB / 7.48 GiB │            │
# └────────┴─────────────────────┴────────────┘
# Epoch 2, Step 9100, Loss: 3.4958109855651855, Elapsed Time: 64.15 seconds
# Generated text after batch 9100:
# The story begins in the midcentury of the American Civil War, with a focus on the war, the military and the war, and the military, as a war between the two sides of the American war, and the military. The war was a common war in the war. The war began in 1887 when the United States entered the United States in 1859.
#
# In 1894, the war was divided into three sections, with the American Civil War. In 1891, the United States became the first to become the United States to be a war, with the United States. The war began in 1894 and ended in 1891, and in 1891, the United States was a war in the war. The United States became the first American to become the United States. The war began in 1887, and in 1894 was a war.
#
# In 1894, the United States was divided into three sections:
#
# In 1891, the United States became the!!!!!!!
#
# TPU Chips
# ┏━━━━━━━━━━━━━┳━━━━━━━━━━━━━┳━━━━━━━━━┳━━━━━━━┓
# ┃ Chip        ┃ Type        ┃ Devices ┃ PID   ┃
# ┡━━━━━━━━━━━━━╇━━━━━━━━━━━━━╇━━━━━━━━━╇━━━━━━━┩
# │ /dev/accel0 │ TPU v2 chip │ 2       │ 83957 │
# │ /dev/accel1 │ TPU v2 chip │ 2       │ 83957 │
# │ /dev/accel2 │ TPU v2 chip │ 2       │ 83957 │
# │ /dev/accel3 │ TPU v2 chip │ 2       │ 83957 │
# └─────────────┴─────────────┴─────────┴───────┘
# Connected to libtpu at grpc://localhost:8431...
# TPU Utilization
# ┏━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┓
# ┃ Device ┃ Memory usage        ┃ Duty cycle ┃
# ┡━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━┩
# │ 0      │ 6.53 GiB / 7.48 GiB │     60.16% │
# │ 1      │ 6.53 GiB / 7.48 GiB │            │
# │ 2      │ 6.53 GiB / 7.48 GiB │     55.85% │
# │ 3      │ 6.53 GiB / 7.48 GiB │            │
# │ 4      │ 6.53 GiB / 7.48 GiB │     51.63% │
# │ 5      │ 6.53 GiB / 7.48 GiB │            │
# │ 6      │ 6.53 GiB / 7.48 GiB │     45.81% │
# │ 7      │ 6.53 GiB / 7.48 GiB │            │
# └────────┴─────────────────────┴────────────┘

# %% [markdown]
# As you can see, the model goes from generating completely random words at the beginning to generating tiny stories at the end of the training. So essentially we have pretrained a small LLM to write tiny stories for us.

# %% [markdown]
# # Saving
# Colab TPU v2 has a problem when saving the model weights. Kaggle TPU v3 works.

# %%
# Don't do this on Colab.

# import orbax.checkpoint as orbax

# state = nnx.state(model)

# checkpointer = orbax.PyTreeCheckpointer()
# checkpointer.save('/kaggle/working/state/', state)

# %% [markdown]
# # Disconnect the Colab runtime

# %%
from google.colab import runtime
runtime.unassign()

wandb.finish()
